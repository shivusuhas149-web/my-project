# %% [markdown]
# <a href="https://colab.research.google.com/github/shivusuhas149-web/my-project/blob/main/Copy_of_Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
my_list=[1,4,5,6]
sum(my_list)
print(my_list)
# Out:
# [1, 4, 5, 6]

# %%
student={
    "Name":"varun",
    "Score":{
        "python":27,
        "maths":88,
  },
}

# %%
numbers=[10,20,30,20,40,10,50]
unique_numbers = []
for num in numbers:
  if num is unique_numbers:
    unique_numbers.append(num)
print("list after removing duplicates:",unique_numbers)
# Out:
# list after removing duplicates: []
# list after removing duplicates: []

# %%
marks={}
for i in range (2):
  subject=input("Enter subject name:")
  score=float(input("enter marks for"+subject+":"))
  marks[subject]=score
  print("marks dictionary:",marks)
# Out:
# Enter subject name:kannada
# enter marks forkannada:98.45
# marks dictionary: {'kannada': 98.45}
# Enter subject name:english
# enter marks forenglish:598
# marks dictionary: {'kannada': 98.45, 'english': 598.0}

# %%
subject={"python","java","c++","python","java script","java","python","java","c++","c"}
classroom=len(subject)
print(f"{classroom} classroom are required")
# Out:
# 5 classroom are required

# %%
s={9,9.0}
print(s)
# Out:
# {9}

# %%
s={9,'9.0'}
print(s)
# Out:
# {9, '9.0'}

# %%
dictionary={
    "table":["A piece of furniture",
             "list of facts and figures"],
    "cat":"A small element"
}
print(dictionary)
# Out:
# {'table': ['A piece of furniture', 'list of facts and figures'], 'cat': 'A small element'}

# %%
numbers=(10,20,30,40,50)
total=sum(numbers)
print(" sum of all the element in the tuple:",total)
# Out:
#  sum of all the element in the tuple: 150
#  sum of all the element in the tuple: 150

# %%
numbers=[10,20,15,24,50,2]
maximum=max(numbers)
minimum=min(numbers)
print("maximum numbers:",maximum)
print("minimum numbers;",minimum)
# Out:
# maximum numbers: 50
# minimum numbers; 2
# maximum numbers: 50
# minimum numbers; 2

# %%
numbers=[10,220,30,2,5]
lowest=min(numbers)
print("lowest numberin the list is:",lowest)
# Out:
# lowest numberin the list is: 2
# lowest numberin the list is: 2

# %%
number=[10,20,30,54,85]
total=len(numbers)
print("total number of the element in the list is:",total)
# Out:
# total number of the element in the list is: 5
# total number of the element in the list is: 5

# %%
my_list=[10,20,30,40,50]
for element in my_list:
    print(element)
# Out:
# 10
# 20
# 30
# 40
# 50
